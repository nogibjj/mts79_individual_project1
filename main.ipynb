# %% [markdown]
# ### We first import all the libraries and functions from mylib/ and main

# %%
from mylib.lib import *
from main import *
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

dataset = sns.load_dataset('diamonds')
dataset.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# ### We then get some summary statistics for each field of the dataset by utilizing `get_summary_statistics()` from mylib/

# %%
get_summary_statistics(dataset)
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %% [markdown]
# ### To get the mode of each field in the dataset, we use the `get_mode()` function from mylib/

# %%
get_mode(dataset)
# Out:
# carat        0.3
# cut        Ideal
# color          G
# clarity      SI1
# depth       62.0
# table       56.0
# price        605
# x           4.37
# y           4.34
# z            2.7
# Name: 0, dtype: object

# %% [markdown]
# ### Getting the variance and standard deviation of the 'price' column using `get_variance_std()` from mylib/

# %%
get_variance_std(dataset, 'price')
# Out:
# (np.float64(15915629.42430145), np.float64(3989.439738146379))

# %% [markdown]
# ### To combine all of the previous summary statistics, we use `generate_full_summary()` from main

# %%
generate_full_summary(dataset)
# Out:
# {'Summary Statistics':               carat         depth         table         price             x  \
#  count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
#  mean       0.797940     61.749405     57.457184   3932.799722      5.731157
#  std        0.474011      1.432621      2.234491   3989.439738      1.121761
#  min        0.200000     43.000000     43.000000    326.000000      0.000000
#  25%        0.400000     61.000000     56.000000    950.000000      4.710000
#  50%        0.700000     61.800000     57.000000   2401.000000      5.700000
#  75%        1.040000     62.500000     59.000000   5324.250000      6.540000
#  max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                    y             z
#  count  53940.000000  53940.000000
#  mean       5.734526      3.538734
#  std        1.142135      0.705699
#  min        0.000000      0.000000
#  25%        4.720000      2.910000
#  50%        5.710000      3.530000
# ...

# %% [markdown]
# ### Now we want to generate a report for the price column specifically, so we utilize `generate_column_report` from main

# %%
generate_column_report(dataset, 'price')
# Out:
# {'Summary Statistics':               price
#  count  53940.000000
#  mean    3932.799722
#  std     3989.439738
#  min      326.000000
#  25%      950.000000
#  50%     2401.000000
#  75%     5324.250000
#  max    18823.000000,
#  'Mode': price    605
#  Name: 0, dtype: int64,
#  'Variance': np.float64(15915629.42430145),
#  'Standard Deviation': np.float64(3989.439738146379)}

# %% [markdown]
# ### Lastly, we generate a visualization that illustrates the distribution of diamonds prices using `generate_viz_diamonds()` from main

# %%
generate_viz_diamonds()

# %%
save_diamonds_report_to_markdown()
